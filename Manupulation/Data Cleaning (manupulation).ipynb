# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("train2.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Renaming column**
#
# dataframe.rename()

# %%
titanic_df.rename(
    {"Pclass" : "Pstatus", "Sex":"Gender"}, axis = 1, inplace = True
)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pstatus  \
# 0            1         0        3
# 1            2         1        1
# 2            3         1        3
# 3            4         1        1
# 4            5         0        3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Handling incorrect Data**

# %%
import numpy as np

# %%
data = pd.DataFrame({
    "id": [1, 3, 5, 7, 9],
    "name": ["Rujan", "Jhon", "Shailesh", "Sujal", "Alex"],  # Added a 5th name
    "age": [18, 19, 20, 21, "55"],
    "gender": ["M", "F", "Z", "M", "M"],
    "income": [400, 100, np.nan, 700, 780],
})

# %%
data.dtypes
# Out:
# id          int64
# name       object
# age        object
# gender     object
# income    float64
# dtype: object

# %%
data
# Out:
#    id      name age gender  income
# 0   1     Rujan  18      M   400.0
# 1   3      Jhon  19      F   100.0
# 2   5  Shailesh  20      Z     NaN
# 3   7     Sujal  21      M   700.0
# 4   9      Alex  55      M   780.0

# %%
data.age = data.age.astype(int)

# %%
# sample Boundary
filter_age = data[(data.age > 10) & (data.age < 45)]

# %%
filter_age
# Out:
#    id      name  age gender  income
# 0   1     Rujan   18      M   400.0
# 1   3      Jhon   19      F   100.0
# 2   5  Shailesh   20      Z     NaN
# 3   7     Sujal   21      M   700.0

# %%
data.age = abs(data.age)

# %%
data
# Out:
#    id      name  age gender  income
# 0   1     Rujan   18      M   400.0
# 1   3      Jhon   19      F   100.0
# 2   5  Shailesh   20      Z     NaN
# 3   7     Sujal   21      M   700.0
# 4   9      Alex   55      M   780.0

# %%
data.gender.isin(["M","F"])
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: gender, dtype: bool

# %%
data[data.gender.isin(["M","F"])]
# Out:
#    id   name  age gender  income
# 0   1  Rujan   18      M   400.0
# 1   3   Jhon   19      F   100.0
# 3   7  Sujal   21      M   700.0
# 4   9   Alex   55      M   780.0

# %% [markdown]
# ### Saving a datagframe
#
# dtaframe.to_csv()

# %%
titanic_df.to_csv("clean_data.csv", index = False)

# %%
titanic_df.to_json("clean_data.json", orient="records", lines=False)
